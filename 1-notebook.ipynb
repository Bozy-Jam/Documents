# %% [markdown]
# # Tarea de Jupyter Notebook

# %% [markdown]
# ## Introducción
#
# Este cuaderno tiene como objetivo proporcionar una introducción básica a los conceptos y herramientas de la Ciencia de Datos. A lo largo de este cuaderno, exploraremos diversos lenguajes, bibliotecas y herramientas utilizadas en este campo.

# %% [markdown]
# ## Lenguajes de la Ciencia de Datos
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Bibliotecas de Ciencia de Datos
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - TensorFlow
# - PyTorch
# - Scikit-learn

# %% [markdown]
# ## Herramientas de Ciencia de Datos
#
# | Herramienta      | Descripción                                     |
# |------------------|-------------------------------------------------|
# | Jupyter Notebook | Entorno interactivo para análisis de datos.     |
# | Git              | Control de versiones de código.                 |
# | Docker           | Contenedores para ejecutar aplicaciones.        |
# | Tableau          | Herramienta de visualización de datos.          |
# | Apache Spark     | Plataforma para procesamiento de grandes datos. |

# %% [markdown]
# ## Ejemplos de Expresiones Aritméticas
#
# A continuación se presentan algunos ejemplos de expresiones aritméticas en Python:
#
# - Suma: `3 + 5`
# - Resta: `10 - 4`
# - Multiplicación: `6 * 7`
# - División: `15 / 3`
# - Exponentes: `2 ** 3`

# %%
# Multiplicar y sumar números
a = 5
b = 3
c = 8

resultado_multiplicacion = a * b
resultado_suma = a + c

resultado_multiplicacion, resultado_suma
# Out:
# (15, 13)

# %%
# Convertir minutos en horas
minutos = 150
horas = minutos / 60

horas
# Out:
# 2.5

# %%
# Objetivos del cuaderno
objetivos = [
    "Aprender sobre los lenguajes de la ciencia de datos",
    "Conocer las bibliotecas más populares",
    "Familiarizarse con herramientas como Jupyter y Git",
    "Realizar operaciones aritméticas básicas"
]

objetivos
# Out:
# ['Aprender sobre los lenguajes de la ciencia de datos',
#  'Conocer las bibliotecas más populares',
#  'Familiarizarse con herramientas como Jupyter y Git',
#  'Realizar operaciones aritméticas básicas']

# %% [markdown]
# ## Autor
#
# Este cuaderno fue creado por Galindo Muñoz José María.
